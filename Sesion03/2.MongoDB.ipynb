# %%
# !python -m pip install "pymongo[srv]"
# Out:
# ...
# WARNING: pymongo 4.16.0 does not provide the extra 'srv'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 18.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pymongo]m1/2 [pymongo]
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python -m pip install --upgrade pip

# %%
# !pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://kremlin:l5SvELdTZN02p2OF@cluster0.hshh7c1.mongodb.net/?appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = client['sample_mflix']

collection = db['movies']

movies = collection.find({})

movies

# %%
import pandas as pd
df_movies = pd.DataFrame(movies)
df_movies
# Out:
#                             _id  \
# 0      573a1390f29313caabcd42e8
# 1      573a1390f29313caabcd446f
# 2      573a1390f29313caabcd4803
# 3      573a1390f29313caabcd4eaf
# 4      573a1390f29313caabcd50e5
# ...                         ...
# 21344  573a13faf29313caabded1d6
# 21345  573a13faf29313caabded406
# 21346  573a13fbf29313caabdedf30
# 21347  573a13fbf29313caabdedf31
# 21348  573a13fbf29313caabdee03b
#
#                                                     plot  \
# 0      A group of bandits stage a brazen train hold-u...
# 1      A greedy tycoon decides, on a whim, to corner ...
# 2      Cartoon figures announce, via comic strip ball...
# 3      A woman, with the aid of her police officer sw...
# 4      The cartoonist, Winsor McCay, brings the Dinos...
# ...                                                  ...
# 21344  A-Gu enlists a group of contract killers in th...
# 21345  Karol, an ordinary young man, runs into a much...
# ...

# %%
# Cargar datos

df_departments = pd.read_csv('./data_retail/departments', sep='|', header=None, names=['department_id', 'department_name'])
df_departments
# Out:
#    department_id department_name
# 0              2         Fitness
# 1              3        Footwear
# 2              4         Apparel
# 3              5            Golf
# 4              6        Outdoors
# 5              7        Fan Shop

# %%
df = df_departments.copy()
df_to_dict = df.to_dict("records")

db = client['retail_db']
collection = db['departments']

collection.insert_many(df_to_dict)
# Out:
# InsertManyResult([ObjectId('698d3c4f02eb36385f21b40c'), ObjectId('698d3c4f02eb36385f21b40d'), ObjectId('698d3c4f02eb36385f21b40e'), ObjectId('698d3c4f02eb36385f21b40f'), ObjectId('698d3c4f02eb36385f21b410'), ObjectId('698d3c4f02eb36385f21b411')], acknowledged=True)
