# %%
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 25.1 MB/s  0:00:00m0:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 49.0 MB/s  0:00:006m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# Dataframes -> tablas en memoria similares a las de una base de datos
# Dataframe -> Listas, Diccionarios, tuplas
import pandas as pd

data = {
    'Nombre': ['Juan', 'Carlos', 'Pedro'],
    'Edad': [25, 30, 35]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#    Nombre  Edad
# 0    Juan    25
# 1  Carlos    30
# 2   Pedro    35

# %%
df = pd.read_csv('./data/data.csv')
df
# Out:
#   nombre  edad     ciudad
# 0   Juan    25     Madrid
# 1  María    30  Barcelona
# 2  Pedro    35    Sevilla

# %%
df = pd.read_csv('./data/data', sep='|')
df
# Out:
#   nombre  edad     ciudad
# 0   Juan   NaN     Madrid
# 1  María  30.0  Barcelona
# 2  Pedro  35.0    Sevilla

# %%
df = pd.read_csv('./data/data_without_header', header=None, names=['nombre', 'edad', 'ciudad'])
df
# Out:
#   nombre  edad     ciudad
# 0   Juan    25     Madrid
# 1  María    30  Barcelona
# 2  Pedro    35    Sevilla

# %%
df = pd.read_json('./data/data.json')
df
# Out:
#   nombre  edad     ciudad
# 0   Juan    25     Madrid
# 1  María    30  Barcelona
# 2  Pedro    35    Sevilla

# %%
df = pd.read_csv('./data/sales_data_sample.csv', encoding='ISO-8859-1')
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
# head

df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.tail()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#            ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2818  12/2/2004 0:00   Shipped       4        12     2004  ...
# 2819  1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820   3/1/2005 0:00  Resolved       1         3     2005  ...
# 2821  3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822   5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                ADDRESSLINE1  ADDRESSLINE2      CITY STATE POSTALCODE  COUNTRY  \
# ...

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='str')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2823, step=1)

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
df[['ORDERNUMBER', 'PRICEEACH', 'SALES']]
# Out:
#       ORDERNUMBER  PRICEEACH    SALES
# 0           10107      95.70  2871.00
# 1           10121      81.35  2765.90
# 2           10134      94.74  3884.34
# 3           10145      83.26  3746.70
# 4           10159     100.00  5205.27
# ...           ...        ...      ...
# 2818        10350     100.00  2244.40
# 2819        10373     100.00  3978.51
# 2820        10386     100.00  5417.57
# 2821        10397      62.24  2116.16
# 2822        10414      65.52  3079.44
#
# [2823 rows x 3 columns]

# %%
df.loc[0]
# Out:
# ORDERNUMBER                           10107
# QUANTITYORDERED                          30
# PRICEEACH                              95.7
# ORDERLINENUMBER                           2
# SALES                                2871.0
# ORDERDATE                    2/24/2003 0:00
# STATUS                              Shipped
# QTR_ID                                    1
# MONTH_ID                                  2
# YEAR_ID                                2003
# PRODUCTLINE                     Motorcycles
# MSRP                                     95
# PRODUCTCODE                        S10_1678
# CUSTOMERNAME              Land of Toys Inc.
# PHONE                            2125557818
# ADDRESSLINE1        897 Long Airport Avenue
# ADDRESSLINE2                            NaN
# CITY                                    NYC
# STATE                                    NY
# POSTALCODE                            10022
# COUNTRY                                 USA
# ...

# %%
df.loc[[1,5]]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 1        10121               34      81.35                5  2765.90
# 5        10168               36      96.66                1  3479.76
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 5  10/28/2003 0:00  Shipped       4        10     2003  ...
#
#          ADDRESSLINE1  ADDRESSLINE2        CITY STATE POSTALCODE COUNTRY  \
# 1  59 rue de l'Abbaye           NaN       Reims   NaN      51100  France
# 5   9408 Furth Circle           NaN  Burlingame    CA      94217     USA
#
#   TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 1      EMEA         Henriot             Paul    Small
# 5       NaN          Hirano             Juri   Medium
#
# [2 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   str
#  6   STATUS            2823 non-null   str
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   str
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   str
#  13  CUSTOMERNAME      2823 non-null   str
#  14  PHONE             2823 non-null   str
#  15  ADDRESSLINE1      2823 non-null   str
#  16  ADDRESSLINE2      302 non-null    str
# ...

# %%
df[df['QTR_ID'] == 2].head()
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 1         10121               34      81.35                5  2765.90
# 11        10237               23     100.00                7  2333.12
# 12        10251               28     100.00                2  3188.64
# 13        10263               34     100.00                2  3676.76
# 24        10403               24     100.00                7  2434.56
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 11   4/5/2004 0:00  Shipped       2         4     2004  ...
# 12  5/18/2004 0:00  Shipped       2         5     2004  ...
# 13  6/28/2004 0:00  Shipped       2         6     2004  ...
# 24   4/8/2005 0:00  Shipped       2         4     2005  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2         CITY STATE POSTALCODE  \
# 1             59 rue de l'Abbaye           NaN        Reims   NaN      51100
# ...

# %%
df.query("STATE == 'NY' and QTR_ID == 1")
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 54          10107               39      99.91                5  3896.49
# 80          10107               27     100.00                4  6065.55
# 240         10107               21     100.00                1  3036.60
# 475         10102               39     100.00                2  4808.31
# 501         10102               41      50.14                1  2055.74
# 804         10107               29      70.87                6  2055.23
# 1466        10107               25     100.00                3  2845.75
# 1564        10107               38      83.03                7  3155.14
# 2173        10107               20      92.90                8  1858.00
#
#            ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0     2/24/2003 0:00  Shipped       1         2     2003  ...
# ...

# %%
df.filter(like = 'ID')
# Out:
#       QTR_ID  MONTH_ID  YEAR_ID
# 0          1         2     2003
# 1          2         5     2003
# 2          3         7     2003
# 3          3         8     2003
# 4          4        10     2003
# ...      ...       ...      ...
# 2818       4        12     2004
# 2819       1         1     2005
# 2820       1         3     2005
# 2821       1         3     2005
# 2822       2         5     2005
#
# [2823 rows x 3 columns]

# %%
total_nulos = df.isnull().sum().sort_values(ascending=False)
total_nulos
# Out:
# ADDRESSLINE2        2521
# STATE               1486
# TERRITORY           1074
# POSTALCODE            76
# SALES                  0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# ORDERNUMBER            0
# MONTH_ID               0
# QTR_ID                 0
# STATUS                 0
# ORDERDATE              0
# PRODUCTCODE            0
# YEAR_ID                0
# MSRP                   0
# PRODUCTLINE            0
# ADDRESSLINE1           0
# PHONE                  0
# CUSTOMERNAME           0
# CITY                   0
# COUNTRY                0
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df['ADDRESSLINE2'] = df['ADDRESSLINE2'].fillna('-')

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue             -            NYC    NY
# ...

# %%
df[['QTR_ID', 'SALES', 'STATE']].groupby(['QTR_ID','STATE']).sum()
# Out:
#                           SALES
# QTR_ID STATE
# 1      CA             567351.70
#        Isle of Wight   26906.68
#        MA             101836.44
#        NH              12133.25
#        NJ               8722.12
#        NSW             65012.42
#        NY              32647.81
#        Osaka           50490.64
#        PA              27398.82
#        Queensland      21730.03
#        Tokyo           38191.39
#        Victoria        49637.57
# 2      BC              31302.50
#        CA             167272.02
#        CT             133103.25
#        MA              96652.51
#        NJ              74506.07
#        NSW             43971.43
#        NV              33847.62
#        NY             165100.34
#        Osaka           17114.43
#        PA              13454.04
#        Quebec          58257.50
#        Tokyo           26482.70
#        Victoria        74513.93
# 3      BC              43332.35
#        CA             348205.38
# ...

# %%
df[['STATE', 'SALES']] \
    .groupby('STATE', as_index=False) \
    .mean() \
    .sort_values(by='SALES', ascending=False) \
    .head(5)
# Out:
#          STATE        SALES
# 13  Queensland  3964.608000
# 6           NJ  3963.247143
# 2           CT  3912.480000
# 5           NH  3873.097059
# 14       Tokyo  3767.585625

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue             -            NYC    NY
# ...

# %%
# dropna -> Elimina filas con datos nulos
# drop_duplicates()
df.drop_duplicates(subset=['STATE'])
# Out:
#      ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0          10107               30      95.70                2  2871.00
# 1          10121               34      81.35                5  2765.90
# 3          10145               45      83.26                6  3746.70
# 10         10223               37     100.00                1  3965.66
# 12         10251               28     100.00                2  3188.64
# 13         10263               34     100.00                2  3676.76
# 15         10285               36     100.00                6  4099.68
# 18         10318               46      94.74                1  4358.04
# 21         10361               20      72.55               13  1451.00
# 32         10174               34     100.00                4  8014.82
# 35         10206               47     100.00                6  9064.89
# 39         10258               32     100.00                6  7680.64
# ...

# %%
df.duplicated(subset=['QTR_ID','STATE']).tail(50)
# Out:
# 2773    True
# 2774    True
# 2775    True
# 2776    True
# 2777    True
# 2778    True
# 2779    True
# 2780    True
# 2781    True
# 2782    True
# 2783    True
# 2784    True
# 2785    True
# 2786    True
# 2787    True
# 2788    True
# 2789    True
# 2790    True
# 2791    True
# 2792    True
# 2793    True
# 2794    True
# 2795    True
# 2796    True
# 2797    True
# 2798    True
# 2799    True
# 2800    True
# 2801    True
# 2802    True
# 2803    True
# 2804    True
# 2805    True
# 2806    True
# 2807    True
# 2808    True
# 2809    True
# 2810    True
# 2811    True
# 2812    True
# 2813    True
# 2814    True
# 2815    True
# 2816    True
# 2817    True
# 2818    True
# 2819    True
# 2820    True
# 2821    True
# 2822    True
# dtype: bool

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df = df.drop_duplicates(subset=['STATE'])
# Out:
#      ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0          10107               30      95.70                2  2871.00
# 1          10121               34      81.35                5  2765.90
# 3          10145               45      83.26                6  3746.70
# 10         10223               37     100.00                1  3965.66
# 12         10251               28     100.00                2  3188.64
# 13         10263               34     100.00                2  3676.76
# 15         10285               36     100.00                6  4099.68
# 18         10318               46      94.74                1  4358.04
# 21         10361               20      72.55               13  1451.00
# 32         10174               34     100.00                4  8014.82
# 35         10206               47     100.00                6  9064.89
# 39         10258               32     100.00                6  7680.64
# ...

# %%
df_copy = df.copy()

# %%
df_copy['SALES3'] = df_copy['SALES']*2

# %%
df_copy
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...
