# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %%
# Creamos variables a, b y c
# a = 5
# b = 6
# c =7
# print(a + b)

# %%
# Indentacion
# if condicion { bloquue1 } else { bloque2 }
# linea 1;

v1 = 5

if v1 == '5':
    print('si son iguales')
    print('si cumple')
else:
    print('no cumple la condicion')
# Out:
# no cumple la condicion

# %%
# Variables -> se crea en el momento que se le asigna un valor

a = 5 # Int

b = '5' # String

c = 2.5 # float

print(a)
print(b)
print(c)
# Out:
# 5
# 5
# 2.5

# %%
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
x, y, z = 'pera', 'manzana', 'platano'

# %%
# Listas -> versatiles 
# lista1 = [1, 2, 3, 4, 5, 6]


lista_vacia = []

lista_enteros = [2, 4, 6]

lista_mixta = [3, 'pera', 44.4]

lista_anidada = ['pera', 3, [3, 4, [2,3,4]], ['x', 'y']]

# %%
lista_mixta = [1, 3, 5, 8, 'pera', 'manzana']

# operador de indice -> []
# indice 0 -> n-1

print(lista_mixta[4])

print(lista_mixta[2])

print(lista_anidada[3][1])
# Out:
# pera
# 5
# y

# %%
lista_mixta[3.0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 lista_mixta[3.0]
#
# TypeError: list indices must be integers or slices, not float

# %%
print(lista_mixta[-2])
# Out:
# pera

# %%
lista_mixta[2:4]
# Out:
# [5, 8]

# %%
lista_mixta = [1, 3, 5, 8, 'pera', 'manzana']

# %%
lista_mixta[0] = 4
print(lista_mixta)
# Out:
# [4, 3, 5, 8, 'pera', 'manzana']

# %%
lista_mixta.append('platano')
print(lista_mixta)
# Out:
# [4, 3, 5, 8, 'pera', 'manzana', 'platano']

# %%
lista_mixta.extend(['mango', 'papaya'])

print(lista_mixta)
# Out:
# [4, 3, 5, 8, 'pera', 'manzana', 'platano', 'mango', 'papaya']

# %%
lista_mixta.append(['mango', 'papaya'])

print(lista_mixta)
# Out:
# [4, 3, 5, 8, 'pera', 'manzana', 'platano', 'mango', 'papaya', ['mango', 'papaya']]

# %%
lista_mixta.pop()
print(lista_mixta)
# Out:
# [4, 3, 5, 8, 'pera', 'manzana', 'platano', 'mango', 'papaya']

# %%
lista_mixta.pop(0)

print(lista_mixta)
# Out:
# [3, 5, 8, 'pera', 'manzana', 'platano', 'mango', 'papaya']

# %%
lista_mixta.remove(8)

print(lista_mixta)
# Out:
# [3, 5, 'pera', 'manzana', 'platano', 'mango', 'papaya']

# %%
# tuplas -> no se pueden modificar una ves asignada 
# tupla1 = ()

tupla_vacioa = ()

tupla_enteros = (3, 5, 6)

tupla_mixta = (3, 'mixta')

tupla_anidada = (4, 'mixta', (5, 6, 7), [1, 2, 3] )

# %%
print(tupla_mixta[0])
# Out:
# 3

# %%
tupla_mixta[0] = 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 tupla_mixta[0] = 3
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Datos de configuracion que no cambien en el tiempo
# Coordenads 
# Claves de diccionario

# %%
# Diccionarios -> {clave1: valor1, clave2:valor2, clave3:valor3  }
# dic1 = { }

diccionario_vacio = {}

diccionario_clave_entera = {1: 'pera', 2:'balon'}

diccionario_clave_mixta = {'nombre': 'John', 1: 'balon'}

# %%
diccionario_persona1 = {'nombre': 'Juan', 'edad': 26, 'sexo':'Masculino', 'direccion': 'calle 1 lot4'}

print(diccionario_persona1['direccion'])
# Out:
# calle 1 lot4

# %%
print(diccionario_persona1['documento'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 print(diccionario_persona1['documento'])
#
# KeyError: 'documento'

# %%
print(diccionario_persona1.get('documento'))
# Out:
# None

# %%
diccionario_persona1['documento'] = 23456789
diccionario_persona1
# Out:
# {'nombre': 'Juan',
#  'edad': 26,
#  'sexo': 'Masculino',
#  'direccion': 'calle 1 lot4',
#  'documento': 23456789}

# %%
diccionario_persona1.popitem()
diccionario_persona1
# Out:
# {'nombre': 'Juan',
#  'edad': 26,
#  'sexo': 'Masculino',
#  'direccion': 'calle 1 lot4'}

# %%
del diccionario_persona1['sexo']

diccionario_persona1
# Out:
# {'nombre': 'Juan', 'edad': 26, 'direccion': 'calle 1 lot4'}

# %%
diccionario_persona1.pop('edad', None)
# Out:
# 26

# %%
diccionario_persona1
# Out:
# {'nombre': 'Juan', 'direccion': 'calle 1 lot4'}

# %%
# Control de flujo
var1 = 5

if var1 == 5:
    print('Si cumple la condicion')
else:
    print('No cumple la condicion')
# Out:
# Si cumple la condicion

# %%
# Nota
nota = 10

if nota >= 18:
    print('Excelente')
elif nota >= 14:
    print('Aprobado')
elif nota >= 11:
    print('Suficiente')
else:
    print('Desaprobado')
# Out:
# Desaprobado

# %%
# for y while -> Iterar

numeros = [1, 2, 5, 6, 7, 9, 10]

suma = 0 

for val in numeros:
    suma = suma + val


print('La suma total es -> ', suma)
# Out:
# La suma total es ->  40

# %%
n = 10
suma = 0 # Acumulador
c = 1  # contador
i = 0
while c <= n:
    suma = suma + c
    c = c + 2
    i = i+1

print(i)
print('la suma total es ->', suma)
# Out:
# 5
# la suma total es -> 25

# %%
# Crea un programa que:
# 	1.	Pida números al usuario usando input().
# 	2.	Los guarde en una lista.
# 	3.	Termine cuando el usuario escriba "fin".
# 	4.	Muestre:
# 	•	La lista completa
# 	•	El número mayor
# 	•	El número menor
# 	•	El promedio

# %%
del sum

# %%
nums = []

while True:
    s = input('Ingrese un numero o escriba fin ').lower()
    if s == 'fin':
        break
    
    n = float(s)
    nums.append(n)

if nums:
    promedio = sum(nums) / len(nums)
    print("lista: ", nums)
    print("Mayor: ", max(nums))
    print("Menor: ", min(nums))
    print("Promedio: ", promedio)
# Out:
# lista:  [12.0, 4.0, 5.0, 16.0]
# Mayor:  16.0
# Menor:  4.0
# Promedio:  9.25

# %%
# Simula un registro de alumnos:
# 	1.	Usa un diccionario donde:
# 	•	clave = nombre del alumno
# 	•	valor = nota final
# 	2.	Pide datos al usuario hasta que escriba "salir".
# 	3.	Luego muestra:
# 	•	Todos los alumnos
# 	•	El alumno con mayor nota
# 	•	El alumno con menor nota

# %%
notas = {}

while True:
    nombre = input('Nombre o salir: ').lower()

    if nombre == 'salir':
        break

    nota = float(input('Nota: '))
    notas[nombre] = nota

if notas:
    print('Registro: ', notas)
    mayor = max(notas, key=notas.get)
    menor = min(notas, key=notas.get)
    print('Mayor: ', mayor)
    print('Menor: ', menor)
# Out:
# Registro:  {'kremlin': 12.0, 'juan': 15.0}
# Mayor:  juan
# Menor:  kremlin
